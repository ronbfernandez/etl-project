# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
# Name of CSV file
movie1 = "Resources/imdb_movies.csv"

# %%
# Import CSV file
movie1_df = pd.read_csv(movie1)

# %%
# Preview of DataFrame
movie1_df.head()
# Out:
#   imdb_title_id                                     title  \
# 0     tt0012494                              Der müde Tod
# 1     tt0013579  Schatten - Eine nächtliche Halluzination
# 2     tt0018054                         The King of Kings
# 3     tt0020286                            Prapancha Pash
# 4     tt0021331                        Le sang d'un poète
#
#                              original_title  year date_published  \
# 0                              Der müde Tod  1921       6/9/2017
# 1  Schatten - Eine nächtliche Halluzination  1923     11/29/2016
# 2                         The King of Kings  1927           2004
# 3                            Prapancha Pash  1929       9/4/2007
# 4                        Le sang d'un poète  1930      5/20/2010
#
#                        genre  duration             country language  \
# 0   Drama, Fantasy, Thriller        97             Germany   German
# 1     Drama, Fantasy, Horror        90             Germany   German
# 2  Biography, Drama, History       155                 USA  English
# 3  Adventure, Drama, Romance        74  UK, India, Germany  English
# 4                    Fantasy        55              France   French
#
#            director  ...                                             actors  \
# 0        Fritz Lang  ...  Bernhard Goetzke, Lil Dagover, Walter Janssen,...
# 1    Arthur Robison  ...  Alexander Granach, Max Gülstorff, Lilli Herder...
# 2  Cecil B. DeMille  ...  H.B. Warner, Dorothy Cumming, Ernest Torrence,...
# 3       Franz Osten  ...  Seeta Devi, Himanshu Rai, Charu Roy, Modhu Bos...
# 4      Jean Cocteau  ...  Enrique Rivero, Elizabeth Lee Miller, Pauline ...
#
#                                          description avg_vote votes  \
# 0  When a woman's fiancé disappears, Death gives ...      7.7  4695
# 1  A wealthy man invites the local wealthy bachel...      6.9   787
# 2  Jesus Christ faces religious and political opp...      7.3  1771
# 3  Two neighboring Indian kingdoms are ruled by c...      6.5   640
# 4  A young artist draws a face at a canvas on his...      7.4  5310
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN          $12,156               $12,156        NaN
# 1          NaN               NaN                   NaN       NaN
# 2  $2,500,000                NaN                   NaN       NaN
# 3          NaN               NaN               $2,306        NaN
# 4          NaN               NaN                   NaN       NaN
#
#   reviews_from_users  reviews_from_critics
# 0               33.0                  41.0
# 1               15.0                  16.0
# 2               46.0                  23.0
# 3                8.0                  14.0
# 4               31.0                  44.0
#
# [5 rows x 22 columns]

# %%
# Deleting extraneous columns
movie1_df.drop(["imdb_title_id", 
                "original_title", 
                "duration", 
                "country", 
                "language", 
                "director", 
                "actors", 
                "writer", 
                "year", 
                "production_company", 
                "avg_vote", 
                "votes", 
                "metascore", 
                "reviews_from_users", 
                "reviews_from_critics"], axis =1, inplace = True)
movie1_df.head()
# Out:
#                                       title date_published  \
# 0                              Der müde Tod       6/9/2017
# 1  Schatten - Eine nächtliche Halluzination     11/29/2016
# 2                         The King of Kings           2004
# 3                            Prapancha Pash       9/4/2007
# 4                        Le sang d'un poète      5/20/2010
#
#                        genre  \
# 0   Drama, Fantasy, Thriller
# 1     Drama, Fantasy, Horror
# 2  Biography, Drama, History
# 3  Adventure, Drama, Romance
# 4                    Fantasy
#
#                                          description       budget  \
# 0  When a woman's fiancé disappears, Death gives ...          NaN
# 1  A wealthy man invites the local wealthy bachel...          NaN
# 2  Jesus Christ faces religious and political opp...  $2,500,000
# 3  Two neighboring Indian kingdoms are ruled by c...          NaN
# 4  A young artist draws a face at a canvas on his...          NaN
#
#   usa_gross_income worlwide_gross_income
# 0         $12,156               $12,156
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN               $2,306
# 4              NaN                   NaN

# %%
# Identifying incomplete gross income rows
movie1_df.count()
# Out:
# title                    54519
# date_published           54519
# genre                    54519
# description              52711
# budget                   18028
# usa_gross_income         12403
# worlwide_gross_income    27254
# dtype: int64

# %%
#removing movies with null/empty us gross income
gross_clean = movie1_df[pd.notnull(movie1_df['usa_gross_income'])]
gross_clean
# Out:
#                         title date_published                         genre  \
# 0                Der müde Tod       6/9/2017      Drama, Fantasy, Thriller
# 7              Kate & Leopold       4/5/2002      Comedy, Fantasy, Romance
# 19            Le roi de coeur       6/8/2018            Drama, Comedy, War
# 24     The Plot Against Harry      5/16/1990                        Comedy
# 27         A Clockwork Orange      3/17/2000          Crime, Drama, Sci-Fi
# ...                       ...            ...                           ...
# 54404         Shao nian de ni     10/25/2019                Drama, Romance
# 54420            Pan deng zhe      9/30/2019      Action, Adventure, Drama
# 54463                 Xue bao      4/20/2019       Action, Crime, Thriller
# 54496            Fin de siglo      8/16/2019                         Drama
# 54511  The Pilgrim's Progress      4/18/2019  Animation, Adventure, Family
#
#                                              description        budget  \
# 0      When a woman's fiancé disappears, Death gives ...           NaN
# 7      An English Duke from 1876 is inadvertedly drag...  $48,000,000
# 19     During World War I, a British private, sent ah...           NaN
# 24     A small-time Jewish racketeer, just out of pri...           NaN
# 27     In the future, a sadistic gang leader is impri...   $2,200,000
# ...                                                  ...           ...
# 54404  A bullied teenage girl forms an unlikely frien...           NaN
# 54420  May 1960. Mount Everest, the second step under...           NaN
# 54463  Buried by treacherous conditions at the top of...           NaN
# 54496  Two men meet in Barcelona and after spending a...           NaN
# 54511  An epic journey, faithfully adapted to modern-...           NaN
#
#       usa_gross_income worlwide_gross_income
# 0             $12,156               $12,156
# 7         $47,121,859           $76,019,048
# 19            $17,646               $18,130
# 24           $274,182                    NaN
# 27        $26,589,355           $26,903,440
# ...                ...                   ...
# 54404      $1,309,002          $199,129,401
# 54420        $487,157          $153,782,355
# 54463         $74,491            $4,140,502
# 54496         $60,380               $60,380
# 54511      $1,294,596            $3,173,282
#
# [12403 rows x 7 columns]

# %%
# Creating new cell so this does not rerun each time. 
# Run to reset movies1_final_df

movie1_final_df = gross_clean.copy()
movie1_final_df
# Out:
#                         title date_published                         genre  \
# 0                Der müde Tod       6/9/2017      Drama, Fantasy, Thriller
# 7              Kate & Leopold       4/5/2002      Comedy, Fantasy, Romance
# 19            Le roi de coeur       6/8/2018            Drama, Comedy, War
# 24     The Plot Against Harry      5/16/1990                        Comedy
# 27         A Clockwork Orange      3/17/2000          Crime, Drama, Sci-Fi
# ...                       ...            ...                           ...
# 54404         Shao nian de ni     10/25/2019                Drama, Romance
# 54420            Pan deng zhe      9/30/2019      Action, Adventure, Drama
# 54463                 Xue bao      4/20/2019       Action, Crime, Thriller
# 54496            Fin de siglo      8/16/2019                         Drama
# 54511  The Pilgrim's Progress      4/18/2019  Animation, Adventure, Family
#
#                                              description        budget  \
# 0      When a woman's fiancé disappears, Death gives ...           NaN
# 7      An English Duke from 1876 is inadvertedly drag...  $48,000,000
# 19     During World War I, a British private, sent ah...           NaN
# 24     A small-time Jewish racketeer, just out of pri...           NaN
# 27     In the future, a sadistic gang leader is impri...   $2,200,000
# ...                                                  ...           ...
# 54404  A bullied teenage girl forms an unlikely frien...           NaN
# 54420  May 1960. Mount Everest, the second step under...           NaN
# 54463  Buried by treacherous conditions at the top of...           NaN
# 54496  Two men meet in Barcelona and after spending a...           NaN
# 54511  An epic journey, faithfully adapted to modern-...           NaN
#
#       usa_gross_income worlwide_gross_income
# 0             $12,156               $12,156
# 7         $47,121,859           $76,019,048
# 19            $17,646               $18,130
# 24           $274,182                    NaN
# 27        $26,589,355           $26,903,440
# ...                ...                   ...
# 54404      $1,309,002          $199,129,401
# 54420        $487,157          $153,782,355
# 54463         $74,491            $4,140,502
# 54496         $60,380               $60,380
# 54511      $1,294,596            $3,173,282
#
# [12403 rows x 7 columns]

# %%
# Checking movie count after removing movies without gross value
movie1_final_df.count()
# Out:
# title                    12403
# date_published           12403
# genre                    12403
# description              12379
# budget                    6955
# usa_gross_income         12403
# worlwide_gross_income    12038
# dtype: int64

# %%
# Name of CSV file #2
movie2 = "Resources/movies.csv"

# %%
# Import of CSV file #2
movie2_df = pd.read_csv(movie2)

# %%
# Preview of DataFrame
movie2_df.head()
# Out:
#    movieid                       title mpaa_rating    budget      gross  \
# 0        1          Look Who's Talking       PG-13   7500000  296000000
# 1        2          Driving Miss Daisy          PG   7500000  145793296
# 2        3              Turner & Hooch          PG  13000000   71079915
# 3        4  Born on the Fourth of July           R  14000000  161001698
# 4        5             Field of Dreams          PG  15000000   84431625
#
#   release_date    genre  runtime  rating  rating_count  \
# 0   10/12/1989  Romance       93     5.9         73638
# 1   12/13/1989   Comedy       99     7.4         91075
# 2    7/28/1989    Crime      100     7.2         91415
# 3   12/20/1989      War      145     7.2         91415
# 4    4/21/1989    Drama      107     7.5        101702
#
#                                              summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...
# 3  The biography of Ron Kovic. Paralyzed in the V...
# 4  An Iowa corn farmer, hearing voices, interpret...

# %%
#Cleaning movie2 CSV Dataframe

# Deleting extraneous columns
movie2_df.drop(["movieid", "rating", "rating_count", "runtime", "mpaa_rating"], axis =1, inplace = True)
movie2_df.head()
# Out:
#                         title    budget      gross release_date    genre  \
# 0          Look Who's Talking   7500000  296000000   10/12/1989  Romance
# 1          Driving Miss Daisy   7500000  145793296   12/13/1989   Comedy
# 2              Turner & Hooch  13000000   71079915    7/28/1989    Crime
# 3  Born on the Fourth of July  14000000  161001698   12/20/1989      War
# 4             Field of Dreams  15000000   84431625    4/21/1989    Drama
#
#                                              summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...
# 3  The biography of Ron Kovic. Paralyzed in the V...
# 4  An Iowa corn farmer, hearing voices, interpret...

# %%
#Renaming columns to match first dataset

movie2_final_df = movie2_df.rename(columns={"release_date":"date_published","summary":"description", "gross":"usa_gross_income"})
movie2_final_df
# Out:
#                           title     budget  usa_gross_income date_published  \
# 0            Look Who's Talking    7500000         296000000     10/12/1989
# 1            Driving Miss Daisy    7500000         145793296     12/13/1989
# 2                Turner & Hooch   13000000          71079915      7/28/1989
# 3    Born on the Fourth of July   14000000         161001698     12/20/1989
# 4               Field of Dreams   15000000          84431625      4/21/1989
# ..                          ...        ...               ...            ...
# 195                    Godzilla  130000000         379014294      5/20/1998
# 196                  Armageddon  140000000         553799566       7/1/1998
# 197             Lethal Weapon 4  140000000         285444603      7/10/1998
# 198     The Blair Witch Project      60000         248000000      7/14/1999
# 199                American Pie   11000000         235483004       7/9/1999
#
#                genre                                        description
# 0            Romance  After a single, career-minded woman is left on...
# 1             Comedy  An old Jewish woman and her African-American c...
# 2              Crime  Det. Scott Turner (Tom Hanks) is an uptight, b...
# 3                War  The biography of Ron Kovic. Paralyzed in the V...
# 4              Drama  An Iowa corn farmer, hearing voices, interpret...
# ..               ...                                                ...
# 195         Thriller  A giant, reptilian monster surfaces, leaving d...
# 196  Science Fiction  After discovering that an asteroid the size of...
# 197           Comedy  With personal crises and age weighing in on th...
# 198           Horror  Three film students vanish after traveling int...
# 199           Comedy  Four teenage boys enter a pact to lose their v...
#
# [200 rows x 6 columns]

# %%
# Changing the order of columns to match 1st movie data set dataframe
movie2_final_df[['title', 'date_published', 'genre', 'description', 'budget', 'usa_gross_income']]
# Out:
#                           title date_published            genre  \
# 0            Look Who's Talking     10/12/1989          Romance
# 1            Driving Miss Daisy     12/13/1989           Comedy
# 2                Turner & Hooch      7/28/1989            Crime
# 3    Born on the Fourth of July     12/20/1989              War
# 4               Field of Dreams      4/21/1989            Drama
# ..                          ...            ...              ...
# 195                    Godzilla      5/20/1998         Thriller
# 196                  Armageddon       7/1/1998  Science Fiction
# 197             Lethal Weapon 4      7/10/1998           Comedy
# 198     The Blair Witch Project      7/14/1999           Horror
# 199                American Pie       7/9/1999           Comedy
#
#                                            description     budget  \
# 0    After a single, career-minded woman is left on...    7500000
# 1    An old Jewish woman and her African-American c...    7500000
# 2    Det. Scott Turner (Tom Hanks) is an uptight, b...   13000000
# 3    The biography of Ron Kovic. Paralyzed in the V...   14000000
# 4    An Iowa corn farmer, hearing voices, interpret...   15000000
# ..                                                 ...        ...
# 195  A giant, reptilian monster surfaces, leaving d...  130000000
# 196  After discovering that an asteroid the size of...  140000000
# 197  With personal crises and age weighing in on th...  140000000
# 198  Three film students vanish after traveling int...      60000
# 199  Four teenage boys enter a pact to lose their v...   11000000
#
#      usa_gross_income
# 0           296000000
# 1           145793296
# 2            71079915
# 3           161001698
# 4            84431625
# ..                ...
# 195         379014294
# 196         553799566
# 197         285444603
# 198         248000000
# 199         235483004
#
# [200 rows x 6 columns]

# %%
# Performed Concat function to merge the Data Sets
concatenated_df = pd.concat([movie1_final_df, movie2_final_df])
concatenated_df.head()
# Out:
#                      title date_published                     genre  \
# 0             Der müde Tod       6/9/2017  Drama, Fantasy, Thriller
# 7           Kate & Leopold       4/5/2002  Comedy, Fantasy, Romance
# 19         Le roi de coeur       6/8/2018        Drama, Comedy, War
# 24  The Plot Against Harry      5/16/1990                    Comedy
# 27      A Clockwork Orange      3/17/2000      Crime, Drama, Sci-Fi
#
#                                           description        budget  \
# 0   When a woman's fiancé disappears, Death gives ...           NaN
# 7   An English Duke from 1876 is inadvertedly drag...  $48,000,000
# 19  During World War I, a British private, sent ah...           NaN
# 24  A small-time Jewish racketeer, just out of pri...           NaN
# 27  In the future, a sadistic gang leader is impri...   $2,200,000
#
#    usa_gross_income worlwide_gross_income
# 0          $12,156               $12,156
# 7      $47,121,859           $76,019,048
# 19         $17,646               $18,130
# 24        $274,182                    NaN
# 27     $26,589,355           $26,903,440

# %%
# checking count of combined movies
concatenated_df.count()
# Out:
# title                    12603
# date_published           12603
# genre                    12603
# description              12579
# budget                    7155
# usa_gross_income         12603
# worlwide_gross_income    12038
# dtype: int64

# %%
#Renaming columns for better description presence
Movies_renamed_df = concatenated_df.rename(columns={"date_published":"release_date","usa_gross_income":"gross_earnings","worlwide_gross_income":"world_wide_earnings"})
Movies_renamed_df.head()
# Out:
#                      title release_date                     genre  \
# 0             Der müde Tod     6/9/2017  Drama, Fantasy, Thriller
# 7           Kate & Leopold     4/5/2002  Comedy, Fantasy, Romance
# 19         Le roi de coeur     6/8/2018        Drama, Comedy, War
# 24  The Plot Against Harry    5/16/1990                    Comedy
# 27      A Clockwork Orange    3/17/2000      Crime, Drama, Sci-Fi
#
#                                           description        budget  \
# 0   When a woman's fiancé disappears, Death gives ...           NaN
# 7   An English Duke from 1876 is inadvertedly drag...  $48,000,000
# 19  During World War I, a British private, sent ah...           NaN
# 24  A small-time Jewish racketeer, just out of pri...           NaN
# 27  In the future, a sadistic gang leader is impri...   $2,200,000
#
#    gross_earnings world_wide_earnings
# 0        $12,156             $12,156
# 7    $47,121,859         $76,019,048
# 19       $17,646             $18,130
# 24      $274,182                  NaN
# 27   $26,589,355         $26,903,440

# %%
# reseting Index for newly combined Movies dataframe and starting new movie df to keep ran updates.
movie3_df = Movies_renamed_df.reset_index(drop=True)
movie3_df
# Out:
#                          title release_date                     genre  \
# 0                 Der müde Tod     6/9/2017  Drama, Fantasy, Thriller
# 1               Kate & Leopold     4/5/2002  Comedy, Fantasy, Romance
# 2              Le roi de coeur     6/8/2018        Drama, Comedy, War
# 3       The Plot Against Harry    5/16/1990                    Comedy
# 4           A Clockwork Orange    3/17/2000      Crime, Drama, Sci-Fi
# ...                        ...          ...                       ...
# 12598                 Godzilla    5/20/1998                  Thriller
# 12599               Armageddon     7/1/1998           Science Fiction
# 12600          Lethal Weapon 4    7/10/1998                    Comedy
# 12601  The Blair Witch Project    7/14/1999                    Horror
# 12602             American Pie     7/9/1999                    Comedy
#
#                                              description        budget  \
# 0      When a woman's fiancé disappears, Death gives ...           NaN
# 1      An English Duke from 1876 is inadvertedly drag...  $48,000,000
# 2      During World War I, a British private, sent ah...           NaN
# 3      A small-time Jewish racketeer, just out of pri...           NaN
# 4      In the future, a sadistic gang leader is impri...   $2,200,000
# ...                                                  ...           ...
# 12598  A giant, reptilian monster surfaces, leaving d...     130000000
# 12599  After discovering that an asteroid the size of...     140000000
# 12600  With personal crises and age weighing in on th...     140000000
# 12601  Three film students vanish after traveling int...         60000
# 12602  Four teenage boys enter a pact to lose their v...      11000000
#
#       gross_earnings world_wide_earnings
# 0           $12,156             $12,156
# 1       $47,121,859         $76,019,048
# 2           $17,646             $18,130
# 3          $274,182                  NaN
# 4       $26,589,355         $26,903,440
# ...              ...                 ...
# 12598      379014294                 NaN
# 12599      553799566                 NaN
# 12600      285444603                 NaN
# 12601      248000000                 NaN
# 12602      235483004                 NaN
#
# [12603 rows x 7 columns]

# %%
movie3_df.head()
# Out:
#                     title release_date                     genre  \
# 0            Der müde Tod     6/9/2017  Drama, Fantasy, Thriller
# 1          Kate & Leopold     4/5/2002  Comedy, Fantasy, Romance
# 2         Le roi de coeur     6/8/2018        Drama, Comedy, War
# 3  The Plot Against Harry    5/16/1990                    Comedy
# 4      A Clockwork Orange    3/17/2000      Crime, Drama, Sci-Fi
#
#                                          description        budget  \
# 0  When a woman's fiancé disappears, Death gives ...           NaN
# 1  An English Duke from 1876 is inadvertedly drag...  $48,000,000
# 2  During World War I, a British private, sent ah...           NaN
# 3  A small-time Jewish racketeer, just out of pri...           NaN
# 4  In the future, a sadistic gang leader is impri...   $2,200,000
#
#   gross_earnings world_wide_earnings
# 0       $12,156             $12,156
# 1   $47,121,859         $76,019,048
# 2       $17,646             $18,130
# 3      $274,182                  NaN
# 4   $26,589,355         $26,903,440

# %%
movie3_df.count()
# Out:
# title                  12603
# release_date           12603
# genre                  12603
# description            12579
# budget                  7155
# gross_earnings         12603
# world_wide_earnings    12038
# dtype: int64

# %%
#Create Engine and connection to Database
engine = create_engine('postgres://postgress:')
conn = engine.connect()
